# %% [markdown]
# ___
#
# <a href='https://www.instagram.com/lanlearning/'> <img src='../pimages/logosmall.png' width="100" height="100"/></a>
# ___
# <center>Copyright LanLearning 2020</center>

# %% [markdown]
# # Let's Review Pandas Part 5!
#
# This review notebook is meant to help you practice and reinforce what you have learned about **adding columns to a DataFrame** during class.

# %% [markdown]
# Import the pandas library as pd below.

# %%
import pandas as pd

# %% [markdown]
# Save the ```national_parks.csv``` file we've provided you as a DataFrame in a variable called ```national_parks```. Display the table. See how it's ordered alphabetically?

# %%
national_parks = pd.read_csv("national_parks.csv")
national_parks # display the table
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# 12      CRLA                       Crater Lake National Park          OR
# 13      CUVA                   Cuyahoga Valley National Park          OH
# 14      DENA               Denali National Park and Preserve          AK
# 15      DEVA                      Death Valley National Park      CA, NV
# 16      DRTO                      Dry Tortugas National Park          FL
# 17      EVER                        Everglades National Park          FL
# 18      GAAR  Gates Of The Arctic National Park and Preserve          AK
# 19      GLAC                           Glacier National Park          MT
# 20      GLBA          Glacier Bay National Park and Preserve          AK
# 21      GRBA                       Great Basin National Park          NV
# 22      GRCA                      Grand Canyon National Park          AZ
# 23      GRSA     Great Sand Dunes National Park and Preserve          CO
# 24      GRSM             Great Smoky Mountains National Park      TN, NC
# 25      GRTE                       Grand Teton National Park          WY
# 26      GUMO               Guadalupe Mountains National Park          TX
# 27      HALE                         Haleakala National Park          HI
# 28      HAVO                  Hawaii Volcanoes National Park          HI
# 29      HOSP                       Hot Springs National Park          AR
# 30      ISRO                       Isle Royale National Park          MI
# 31      JOTR                       Joshua Tree National Park          CA
# 32      KATM               Katmai National Park and Preserve          AK
# 33      KEFJ                      Kenai Fjords National Park          AK
# 34      KOVA                      Kobuk Valley National Park          AK
# 35      LACL           Lake Clark National Park and Preserve          AK
# 36      LAVO                   Lassen Volcanic National Park          CA
# 37      MACA                      Mammoth Cave National Park          KY
# 38      MEVE                        Mesa Verde National Park          CO
# 39      MORA                     Mount Rainier National Park          WA
# 40      NOCA                    North Cascades National Park          WA
# 41      OLYM                           Olympic National Park          WA
# 42      PEFO                  Petrified Forest National Park          AZ
# 43      PINN                         Pinnacles National Park          CA
# 44      REDW                           Redwood National Park          CA
# 45      ROMO                    Rocky Mountain National Park          CO
# 46      SAGU                           Saguaro National Park          AZ
# 47      SEKI         Sequoia and Kings Canyon National Parks          CA
# 48      SHEN                        Shenandoah National Park          VA
# 49      THRO                Theodore Roosevelt National Park          ND
# 50      VOYA                         Voyageurs National Park          MN
# 51      WICA                         Wind Cave National Park          SD
# 52      WRST  Wrangell - St Elias National Park and Preserve          AK
# 53      YELL                       Yellowstone National Park  WY, MT, ID
# 54      YOSE                          Yosemite National Park          CA
# 55      ZION                              Zion National Park          UT
#
#       Acres  Latitude  Longitude
# 0     47390     44.35     -68.21
# 1     76519     38.68    -109.57
# 2    242756     43.75    -102.50
# 3    801163     29.25    -103.25
# 4    172924     25.65     -80.08
# 5     32950     38.57    -107.72
# 6     35835     37.57    -112.18
# 7    337598     38.20    -109.93
# 8    241904     38.20    -111.17
# 9     46766     32.17    -104.44
# 10   249561     34.01    -119.42
# 11    26546     33.78     -80.78
# 12   183224     42.94    -122.10
# 13    32950     41.24     -81.55
# 14  3372402     63.33    -150.50
# 15  4740912     36.24    -116.82
# 16    64701     24.63     -82.87
# 17  1508538     25.32     -80.93
# 18  7523898     67.78    -153.30
# 19  1013572     48.80    -114.00
# 20  3224840     58.50    -137.00
# 21    77180     38.98    -114.30
# 22  1217403     36.06    -112.14
# 23    42984     37.73    -105.51
# 24   521490     35.68     -83.53
# 25   309995     43.73    -110.80
# 26    86416     31.92    -104.87
# 27    29094     20.72    -156.17
# 28   323431     19.38    -155.20
# 29     5550     34.51     -93.05
# 30   571790     48.10     -88.55
# 31   789745     33.79    -115.90
# 32  3674530     58.50    -155.00
# 33   669983     59.92    -149.65
# 34  1750717     67.55    -159.28
# 35  2619733     60.97    -153.42
# 36   106372     40.49    -121.51
# 37    52830     37.18     -86.10
# 38    52122     37.18    -108.49
# 39   235625     46.85    -121.75
# 40   504781     48.70    -121.20
# 41   922651     47.97    -123.50
# 42    93533     35.07    -109.78
# 43    26606     36.48    -121.16
# 44   112512     41.30    -124.00
# 45   265828     40.40    -105.58
# 46    91440     32.25    -110.50
# 47   865952     36.43    -118.68
# 48   199045     38.53     -78.35
# 49    70447     46.97    -103.45
# 50   218200     48.50     -92.88
# 51    28295     43.57    -103.48
# 52  8323148     61.00    -142.00
# 53  2219791     44.60    -110.50
# 54   761266     37.83    -119.50
# 55   146598     37.30    -113.05

# %% [markdown]
# ### Vocab

# %% [markdown]
# Replace the lines below with your answers to make the sentence correct.

# %% [markdown]
# ```Feature``` ```engineering``` is the important skill and useful technique of creating new columns and using them to analyze the data in addition to building prediction models.

# %% [markdown]
# ### Sorting

# %% [markdown]
# If you wanted to order the rows in your DataFrame based on the values of a certain column, what method would you call? Write it down below.

# %% [markdown]
# .sort_values()

# %% [markdown]
# By default, in what order will that method sort those values?

# %% [markdown]
# ascending

# %% [markdown]
# You would like to sort ```national_parks``` in the reverse order it is in now, based on the ```"Park Name"``` (meaning Zion National Park would be in the first row and Acadia National Park would be last). Save the reordered DataFrame in a variable called ```parks_reverse_order```. Display ```parks_reverse_order``` to check your answer.

# %%
parks_reverse_order = national_parks.sort_values("Park Name", ascending = False)
parks_reverse_order
# Out:
#    Park Code                                       Park Name       State  \
# 50   218200     48.50     -92.88         219200  Neither Coast
# 49    70447     46.97    -103.45          71447  Neither Coast
# 48   199045     38.53     -78.35         200045     East Coast
# 47   865952     36.43    -118.68         866952     West Coast
# 46    91440     32.25    -110.50          92440  Neither Coast
# 45   265828     40.40    -105.58         266828  Neither Coast
# 44   112512     41.30    -124.00         113512     West Coast
# 43    26606     36.48    -121.16          27606     West Coast
# 42    93533     35.07    -109.78          94533  Neither Coast
# 41   922651     47.97    -123.50         923651     West Coast
# 40   504781     48.70    -121.20         505781     West Coast
# 39   235625     46.85    -121.75         236625     West Coast
# 38    52122     37.18    -108.49          53122  Neither Coast
# 37    52830     37.18     -86.10          53830  Neither Coast
# 36   106372     40.49    -121.51         107372     West Coast
# 35  2619733     60.97    -153.42        2620733  Neither Coast
# 34  1750717     67.55    -159.28        1751717  Neither Coast
# 33   669983     59.92    -149.65         670983  Neither Coast
# 32  3674530     58.50    -155.00        3675530  Neither Coast
# 31   789745     33.79    -115.90         790745     West Coast
# 30   571790     48.10     -88.55         572790  Neither Coast
# 29     5550     34.51     -93.05           6550  Neither Coast
# 28   323431     19.38    -155.20         324431  Neither Coast
# 27    29094     20.72    -156.17          30094  Neither Coast
# 26    86416     31.92    -104.87          87416  Neither Coast
# 24   521490     35.68     -83.53         522490  Neither Coast
# 23    42984     37.73    -105.51          43984  Neither Coast
# 21    77180     38.98    -114.30          78180  Neither Coast
# 25   309995     43.73    -110.80         310995  Neither Coast
# 22  1217403     36.06    -112.14        1218403  Neither Coast
# 19  1013572     48.80    -114.00        1014572  Neither Coast
# 20  3224840     58.50    -137.00        3225840  Neither Coast
# 18  7523898     67.78    -153.30        7524898  Neither Coast
# 17  1508538     25.32     -80.93        1509538     East Coast
# 16    64701     24.63     -82.87          65701     East Coast
# 14  3372402     63.33    -150.50        3373402  Neither Coast
# 15  4740912     36.24    -116.82        4741912  Neither Coast
# 13    32950     41.24     -81.55          33950  Neither Coast
# 12   183224     42.94    -122.10         184224     West Coast
# 11    26546     33.78     -80.78          27546     East Coast
# 10   249561     34.01    -119.42         250561     West Coast
# 9     46766     32.17    -104.44          47766  Neither Coast
# 8    241904     38.20    -111.17         242904  Neither Coast
# 7    337598     38.20    -109.93         338598  Neither Coast
# 6     35835     37.57    -112.18          36835  Neither Coast
# 5     32950     38.57    -107.72          33950  Neither Coast
# 4    172924     25.65     -80.08         173924     East Coast
# 3    801163     29.25    -103.25         802163  Neither Coast
# 2    242756     43.75    -102.50         243756  Neither Coast
# 1     76519     38.68    -109.57          77519  Neither Coast
# 0     47390     44.35     -68.21          48390     East Coast

# %% [markdown]
# Now, you would like to order ```national_parks``` based on the number of ```"Acres"``` the park has. Sort ```national_parks``` so the park with the least acres is at the top and the park with the most acres is at the bottom. Save it a variable called ```acres```, and display the frame.

# %%
acres = national_parks.sort_values("Acres")
acres
# Out:
#    Park Code                                       Park Name       State  \
# 29      HOSP                       Hot Springs National Park          AR
# 11      CONG                          Congaree National Park          SC
# 38    52122     37.18    -108.49
# 37    52830     37.18     -86.10
# 16    64701     24.63     -82.87
# 49    70447     46.97    -103.45
# 1     76519     38.68    -109.57
# 21    77180     38.98    -114.30
# 26    86416     31.92    -104.87
# 46    91440     32.25    -110.50
# 42    93533     35.07    -109.78
# 36   106372     40.49    -121.51
# 44   112512     41.30    -124.00
# 55   146598     37.30    -113.05
# 4    172924     25.65     -80.08
# 12   183224     42.94    -122.10
# 48   199045     38.53     -78.35
# 50   218200     48.50     -92.88
# 39   235625     46.85    -121.75
# 8    241904     38.20    -111.17
# 2    242756     43.75    -102.50
# 10   249561     34.01    -119.42
# 45   265828     40.40    -105.58
# 25   309995     43.73    -110.80
# 28   323431     19.38    -155.20
# 7    337598     38.20    -109.93
# 40   504781     48.70    -121.20
# 24   521490     35.68     -83.53
# 30   571790     48.10     -88.55
# 33   669983     59.92    -149.65
# 54   761266     37.83    -119.50
# 31   789745     33.79    -115.90
# 3    801163     29.25    -103.25
# 47   865952     36.43    -118.68
# 41   922651     47.97    -123.50
# 19  1013572     48.80    -114.00
# 22  1217403     36.06    -112.14
# 17  1508538     25.32     -80.93
# 34  1750717     67.55    -159.28
# 53  2219791     44.60    -110.50
# 35  2619733     60.97    -153.42
# 20  3224840     58.50    -137.00
# 14  3372402     63.33    -150.50
# 32  3674530     58.50    -155.00
# 15  4740912     36.24    -116.82
# 18  7523898     67.78    -153.30
# 52  8323148     61.00    -142.00

# %% [markdown]
# ### Adding Columns

# %% [markdown]
# When you want to add a new column to your DataFrame, what are the two necessary things you need to have regarding the column?

# %% [markdown]
# The unique column label and the list of values for the new column.

# %% [markdown]
# Below is the general format you want to follow when you add a new column to a DataFrame. Replace the lines with your answers to make the format correct.

# %% [markdown]
# df_name[```"new_column_name"```] = [```list_of_values```]

# %% [markdown]
# Pretend a new law was passed expanding all national parks in the U.S by an extra 1000 acres. Add a new column to ```national_parks``` called ```"Updated Acres"``` whose values are the expanded acreage. Display the updated DataFrame ```national_parks```.

# %%
national_parks["Updated Acres"] = national_parks["Acres"] + 1000
national_parks
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# 12      CRLA                       Crater Lake National Park          OR
# 13      CUVA                   Cuyahoga Valley National Park          OH
# 14      DENA               Denali National Park and Preserve          AK
# 15      DEVA                      Death Valley National Park      CA, NV
# 16      DRTO                      Dry Tortugas National Park          FL
# 17      EVER                        Everglades National Park          FL
# 18      GAAR  Gates Of The Arctic National Park and Preserve          AK
# 29     5550     34.51     -93.05           6550
# 30   571790     48.10     -88.55         572790
# 31   789745     33.79    -115.90         790745
# 32  3674530     58.50    -155.00        3675530
# 33   669983     59.92    -149.65         670983
# 34  1750717     67.55    -159.28        1751717
# 35  2619733     60.97    -153.42        2620733
# 36   106372     40.49    -121.51         107372
# 37    52830     37.18     -86.10          53830
# 38    52122     37.18    -108.49          53122
# 39   235625     46.85    -121.75         236625
# 40   504781     48.70    -121.20         505781
# 41   922651     47.97    -123.50         923651
# 42    93533     35.07    -109.78          94533
# 43    26606     36.48    -121.16          27606
# 44   112512     41.30    -124.00         113512
# 45   265828     40.40    -105.58         266828
# 46    91440     32.25    -110.50          92440
# 47   865952     36.43    -118.68         866952
# 48   199045     38.53     -78.35         200045
# 49    70447     46.97    -103.45          71447
# 50   218200     48.50     -92.88         219200
# 51    28295     43.57    -103.48          29295
# 52  8323148     61.00    -142.00        8324148
# 53  2219791     44.60    -110.50        2220791
# 54   761266     37.83    -119.50         762266
# 55   146598     37.30    -113.05         147598

# %% [markdown]
# ### Applying Funtions to a Column

# %% [markdown]
# You would like to add a new column to ```national_parks``` that gives the (very, very) general location of each national park. This new column will be labeled ```"General Area"``` and have values of ```"West Coast"```, ```"East Coast"```, and ```"Neither Coast"```. <br> <br> First, you need to **define a method** called ```get_general_area(state)``` which **takes in the state** (which is a String, as all the values in the ```State``` column are Strings) that the national park is located in, and **returns either ```"West Coast"```, ```"East Coast"```, or ```"Neither Coast"``` (all String values) depending on the given state**. We've provided you lists of all the states that are on each coast for you to use in your function. (**Hint**: remember all the way back to python4? We used the membership operator ```in``` to check if a value was in another value. You might want to use it here.) <br> <br> Note: a few of the national parks are located in multiple states as you can tell by the comma separating the state abbreviations. These select national parks will always return ```"Neither Coast"``` because its ```State``` attribute is longer than the Strings in the coast lists. Example: ```"CA, NV"``` can never be in ```"CA"``` because it's bigger! You don't need to do anything about this though. You can just let it be. Just code the function as if the given value was only one state.

# %%
def get_general_area(state):
    west_coast_states = ["CA", "OR", "WA"]
    east_coast_states = ["FL", "GA", "SC", "NC", "VA", "MD", "DE", "NJ", "NY", "CT", "RI", "MA", "NH", "ME"]
    if state in west_coast_states:
        return "West Coast"
    elif state in east_coast_states:
        return "East Coast"
    else:
        return "Neither Coast"

# %% [markdown]
# Now that you've defined the function ```get_general_area(state)```, you want to apply it to the approriate column using  ```.apply()```. Make sure to save the returned list in a variable called ```coast_list```.

# %%
coast_list = national_parks["State"].apply(get_general_area)
coast_list
# Out:
# 0        East Coast
# 1     Neither Coast
# 2     Neither Coast
# 3     Neither Coast
# 4        East Coast
# 5     Neither Coast
# 6     Neither Coast
# 7     Neither Coast
# 8     Neither Coast
# 9     Neither Coast
# 10       West Coast
# 11       East Coast
# 12       West Coast
# 13    Neither Coast
# 14    Neither Coast
# 15    Neither Coast
# 16       East Coast
# 17       East Coast
# 18    Neither Coast
# 19    Neither Coast
# 20    Neither Coast
# 21    Neither Coast
# 22    Neither Coast
# 23    Neither Coast
# 24    Neither Coast
# 25    Neither Coast
# 26    Neither Coast
# 27    Neither Coast
# 28    Neither Coast
# 29    Neither Coast
# 30    Neither Coast
# 31       West Coast
# 32    Neither Coast
# 33    Neither Coast
# 34    Neither Coast
# 35    Neither Coast
# 36       West Coast
# 37    Neither Coast
# 38    Neither Coast
# 39       West Coast
# 40       West Coast
# 41       West Coast
# 42    Neither Coast
# 43       West Coast
# 44       West Coast
# 45    Neither Coast
# 46    Neither Coast
# 47       West Coast
# 48       East Coast
# 49    Neither Coast
# 50    Neither Coast
# 51    Neither Coast
# 52    Neither Coast
# 53    Neither Coast
# 54       West Coast
# 55    Neither Coast
# Name: State, dtype: object

# %% [markdown]
# You're almost done! Now, all you have to do is add the new column using its column label ```"General Area"``` and its list of values ```coast_list``` to ```national_parks```. Display the updated table!

# %%
national_parks["General Area"] = coast_list
national_parks
# Out:
#    Park Code                                       Park Name       State  \
# 0       ACAD                            Acadia National Park          ME
# 1       ARCH                            Arches National Park          UT
# 2       BADL                          Badlands National Park          SD
# 3       BIBE                          Big Bend National Park          TX
# 4       BISC                          Biscayne National Park          FL
# 5       BLCA      Black Canyon of the Gunnison National Park          CO
# 6       BRCA                      Bryce Canyon National Park          UT
# 7       CANY                       Canyonlands National Park          UT
# 8       CARE                      Capitol Reef National Park          UT
# 9       CAVE                  Carlsbad Caverns National Park          NM
# 10      CHIS                   Channel Islands National Park          CA
# 11      CONG                          Congaree National Park          SC
# 12      CRLA                       Crater Lake National Park          OR
# 13      CUVA                   Cuyahoga Valley National Park          OH
# 14      DENA               Denali National Park and Preserve          AK
# 15      DEVA                      Death Valley National Park      CA, NV
# 16      DRTO                      Dry Tortugas National Park          FL
# 17      EVER                        Everglades National Park          FL
# 18      GAAR  Gates Of The Arctic National Park and Preserve          AK
# 19      GLAC                           Glacier National Park          MT
# 20      GLBA          Glacier Bay National Park and Preserve          AK
# 21      GRBA                       Great Basin National Park          NV
# 22      GRCA                      Grand Canyon National Park          AZ
# 23      GRSA     Great Sand Dunes National Park and Preserve          CO
# 24      GRSM             Great Smoky Mountains National Park      TN, NC
# 25      GRTE                       Grand Teton National Park          WY
# 26      GUMO               Guadalupe Mountains National Park          TX
# 27      HALE                         Haleakala National Park          HI
# 28      HAVO                  Hawaii Volcanoes National Park          HI
# 29      HOSP                       Hot Springs National Park          AR
# 30      ISRO                       Isle Royale National Park          MI
# 31      JOTR                       Joshua Tree National Park          CA
# 32      KATM               Katmai National Park and Preserve          AK
# 33      KEFJ                      Kenai Fjords National Park          AK
# 34      KOVA                      Kobuk Valley National Park          AK
# 35      LACL           Lake Clark National Park and Preserve          AK
# 36      LAVO                   Lassen Volcanic National Park          CA
# 37      MACA                      Mammoth Cave National Park          KY
# 38      MEVE                        Mesa Verde National Park          CO
# 39      MORA                     Mount Rainier National Park          WA
# 40      NOCA                    North Cascades National Park          WA
# 41      OLYM                           Olympic National Park          WA
# 42      PEFO                  Petrified Forest National Park          AZ
# 45   265828     40.40    -105.58         266828  Neither Coast
# 46    91440     32.25    -110.50          92440  Neither Coast
# 47   865952     36.43    -118.68         866952     West Coast
# 48   199045     38.53     -78.35         200045     East Coast
# 49    70447     46.97    -103.45          71447  Neither Coast
# 50   218200     48.50     -92.88         219200  Neither Coast
# 51    28295     43.57    -103.48          29295  Neither Coast
# 52  8323148     61.00    -142.00        8324148  Neither Coast
# 53  2219791     44.60    -110.50        2220791  Neither Coast
# 54   761266     37.83    -119.50         762266     West Coast
# 55   146598     37.30    -113.05         147598  Neither Coast

# %% [markdown]
# ### One Last thing###
# Lets see if we can make a column that plots both coordinates which are latitude, longitude using a .apply with two parameters.

# %% [markdown]
# First make a normal function that uses two paremeters to return them in the format of a coordinate. Don't forget return can have multiple outputs if you seperate them with a comma.

# %%
def coordinate(lat,long):
    return lat, long
coordinate(1,2)
# Out:
# (1, 2)

# %% [markdown]
# now use .apply with lambda to create a new column called coordinates

# %%
national_parks['coordinate']=national_parks.apply(lambda x: coordinate(x['Latitude'], x['Longitude']), axis=1)
national_parks.head(10)
# Out:
#   Park Code                                   Park Name State   Acres  \
# 0      ACAD                        Acadia National Park    ME   47390
# 1      ARCH                        Arches National Park    UT   76519
# 2      BADL                      Badlands National Park    SD  242756
# 3      BIBE                      Big Bend National Park    TX  801163
# 4      BISC                      Biscayne National Park    FL  172924
# 5      BLCA  Black Canyon of the Gunnison National Park    CO   32950
# 6      BRCA                  Bryce Canyon National Park    UT   35835
# 7      CANY                   Canyonlands National Park    UT  337598
# 8      CARE                  Capitol Reef National Park    UT  241904
# 9      CAVE              Carlsbad Caverns National Park    NM   46766
#
#    Latitude  Longitude        coordinate
# 0     44.35     -68.21   (44.35, -68.21)
# 1     38.68    -109.57  (38.68, -109.57)
# 2     43.75    -102.50   (43.75, -102.5)
# 3     29.25    -103.25  (29.25, -103.25)
# 4     25.65     -80.08   (25.65, -80.08)
# 5     38.57    -107.72  (38.57, -107.72)
# 6     37.57    -112.18  (37.57, -112.18)
# 7     38.20    -109.93   (38.2, -109.93)
# 8     38.20    -111.17   (38.2, -111.17)
# 9     32.17    -104.44  (32.17, -104.44)

# %% [markdown]
# ## Done!! :)

# %% [markdown]
# ### About this notebook:
# #### Developed by:
# * [Kyra Yee](https://www.linkedin.com/in/kyrayee/)
# * [Liam McDonoguh](https://www.linkedin.com/in/liammmcdonough/)
#
# #### Connect with us:
# <a href='https://www.linkedin.com/company/lanlearning/'> <img src=https://img.icons8.com/color/48/000000/linkedin.png width="48" height="48" align="left"/></a>
#
# <a href='http://www.instagram.com/lanlearning'> <img src=https://img.icons8.com/fluent/48/000000/instagram-new.png width="48" height="48" align="left"/></a>
#
# <a href='https://www.youtube.com/channel/UC5_yxU9pz4ka7xITJMxO5WA'> <img src=https://img.icons8.com/color/48/000000/youtube-squared.png width="48" height="48" align="left"/></a>
#
# <a href='https://www.github.com/lanlearning/'> <img src=https://img.icons8.com/material-rounded/48/000000/github.png/ width="48" height="48" align="left"/></a>
