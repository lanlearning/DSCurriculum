# %% [markdown]
# <a href='https://www.instagram.com/lanlearning/'> <img src='../pimages/logosmall.png' width="100" height="100"/></a>
# ___
# <center>Copyright LanLearning 2020</center>

# %% [markdown]
# # Let's Review Pandas Part 3!
#
# This review notebook is meant to help you practice and reinforce what you have learned about **how to access specified, more complex information about a DataFrame** during class.

# %% [markdown]
# Please import the pandas library as pd below.

# %%
import pandas as pd

# %% [markdown]
# Save the ```astronauts.csv``` file we've provided you as a DataFrame in a variable called ```astronauts```. Display the table.

# %%
astronauts = pd.read_csv("astronauts.csv")
astronauts # display the table
# Out:
#                       Name    Year  Group   Status Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active  5/17/1967
# 1           Loren W. Acton     NaN    NaN  Retired   3/7/1936
# 2         James C. Adamson  1984.0   10.0  Retired   3/3/1946
# 3          Thomas D. Akers  1987.0   12.0  Retired  5/20/1951
# 4              Buzz Aldrin  1963.0    3.0  Retired  1/20/1930
# ..                     ...     ...    ...      ...        ...
# 352          David A. Wolf  1990.0   13.0  Retired  8/23/1956
# 353  Neil W. Woodward III   1998.0   17.0  Retired  7/26/1962
# 354       Alfred M. Worden  1966.0    5.0  Retired   2/7/1932
# 355          John W. Young  1962.0    2.0  Retired  9/24/1930
# 356        George D. Zamka  1998.0   17.0  Retired  6/29/1962
#
#            Birth Place Gender  \
# 0        Inglewood, CA   Male
# 1         Lewiston, MT   Male
# 2           Warsaw, NY   Male
# 3        St. Louis, MO   Male
# 4        Montclair, NJ   Male
# ..                 ...    ...
# ...

# %% [markdown]
# ### Exploration Time!

# %% [markdown]
# If you wanted access to statistical insights about a DataFrame's columns whose values are numerical, what method could you use?

# %% [markdown]
# .describe()

# %% [markdown]
# What kind of statistical insights would that method provide? List several below.

# %% [markdown]
# count, mean, std, min, max

# %% [markdown]
# Replace the lines below with your answers to make the sentence correct.

# %% [markdown]
# There are two methods you could use to find the unique values in a column in a dataset. There is ```.unique()``` or ```set()```.

# %% [markdown]
# Using one of the answers you provided above, find the number of unique values in the ```Undergraduate Major``` column of ```astronauts```. Print your answer.

# %%
print(len(astronauts["Undergraduate Major"].unique()))
# Out:
# 84

# %% [markdown]
# Using the other answer you provided, find the number of unique values in the ```Undergraduate Major``` column of ```astronauts```. Print your answer. You should get the same number as the one above.

# %%
print(len(set(astronauts["Undergraduate Major"])))
# Out:
# 84

# %% [markdown]
# ### Keeping Track of Our Values

# %% [markdown]
# Replace the line below with your answer to make the sentence correct.

# %% [markdown]
# If you want to see how many times each value appears in its column, you can use the method ```.value_counts()```.

# %% [markdown]
# Call the method you answered above on the ```Gender``` column in ```astronauts``` and save it in a variable called ```gender_count```. Print ```gender_count```.

# %%
gender_count = astronauts["Gender"].value_counts()
print(gender_count)
# Out:
# Male      307
# Female     50
# Name: Gender, dtype: int64

# %% [markdown]
# We're going to use ```gender_count``` to see what percentage of astronauts are female. First, cast ```gender_count``` as a dictionary (by using ```dict()```) and store it in ```gc_dict```. Print ```gc_dict```.

# %%
gc_dict = dict(gender_count)
print(gc_dict)
# Out:
# {'Male': 307, 'Female': 50}

# %% [markdown]
# Then, index ```gc_dict``` and use the appropriate arithmetic operator to find the percentage of females in ```astronauts```. Print the percentage.

# %%
percentage = gc_dict["Female"] / sum(gc_dict.values())
print(percentage)
# Out:
# 0.1400560224089636

# %% [markdown]
# ### Target Practice

# %% [markdown]
# Below is the format you should follow when you only want to access the parts of the DataFrame where the values in ```column``` are equal to ```item```. Please fill in the blanks to finalize the format.

# %% [markdown]
# data_frame[```data_frame```[column] ```==``` item]

# %% [markdown]
# Replace the lines below with your answers to make the sentence correct.

# %% [markdown]
# Inside of the outermost pair of brackets (in the format above), you need to pass in a ```conditional``` statement which will return a ```series``` of ```booleans``` to slice into the DataFrame.

# %% [markdown]
# Access the portion of the DataFrame ```astronauts``` where the values in the ```Status``` column are equal to ```"Active"``` and store it in a variable called ```active_astronauts```. Display ```active_astronauts```.

# %%
active_astronauts = astronauts[astronauts["Status"] == "Active"]
active_astronauts
# Out:
#                                 Name    Year  Group  Status  Birth Date  \
# 0                    Joseph M. Acaba  2004.0   19.0  Active   5/17/1967
# 11              Dominic A. Antonelli  2000.0   18.0  Active   8/23/1967
# 15             Richard R. Arnold II   2004.0   19.0  Active  11/26/1963
# 17                   Serena M. Aunon  2009.0   20.0  Active    4/9/1976
# 21                Michael R. Barratt  2000.0   18.0  Active   4/16/1959
# 26                 Robert L. Behnken  2000.0   18.0  Active   7/28/1970
# 31                       Eric A. Boe  2000.0   18.0  Active   10/1/1964
# 34                  Stephen G. Bowen  2000.0   18.0  Active   2/13/1964
# 39               Randolph J. Bresnik  2004.0   19.0  Active   9/11/1967
# 47                 Daniel C. Burbank  1996.0   16.0  Active   7/27/1961
# 52         Tracy E. Caldwell (Dyson)  1998.0   17.0  Active   8/14/1969
# 60            Christopher J. Cassidy  2004.0   19.0  Active    1/4/1970
# ...

# %% [markdown]
# Using your variable ```active_astronauts```, find how many rows in ```astronauts``` are ```"Active"```. Print your answer.

# %%
print(len(active_astronauts))
# Out:
# 50

# %% [markdown]
# ### Passing All (or Some of) the Tests

# %% [markdown]
# Replace the lines below with your answers to make the sentence correct.

# %% [markdown]
# When you want both (two out of two) conditions to be met, you should use the symbol ```&```. When you want only one of two conditions to be met, you should use the symbol ```|```.

# %% [markdown]
# Find the portion of the DataFrame ```astronauts``` where ```"Gender"``` is equal to ```"Female"``` **and** ```Status``` is equal to ```"Active"```.

# %%
astronauts[(astronauts["Gender"] == "Female") & (astronauts["Status"] == "Active")]
# Out:
#                                 Name    Year  Group  Status  Birth Date  \
# 17                   Serena M. Aunon  2009.0   20.0  Active    4/9/1976
# 52         Tracy E. Caldwell (Dyson)  1998.0   17.0  Active   8/14/1969
# 75              Catherine G. Coleman  1992.0   14.0  Active  12/14/1960
# 101                 Jeanette J. Epps  2009.0   20.0  Active   11/3/1970
# 217                K. Megan McArthur  2000.0   18.0  Active   8/30/1971
# 231  Dorothy M. Metcalf-Lindenberger  2004.0   19.0  Active    5/2/1975
# 244                  Karen L. Nyberg  2000.0   18.0  Active   10/7/1969
# 280                  Kathleen Rubins  2009.0   20.0  Active  10/14/1978
# 308                  Nicole P. Stott  2000.0   18.0  Active  11/19/1962
# 334                   Shannon Walker  2004.0   19.0  Active    6/4/1965
# 342                 Peggy A. Whitson  1996.0   16.0  Active    2/9/1960
# 347               Sunita L. Williams  1998.0   17.0  Active   9/19/1965
# ...

# %% [markdown]
# Now, find the portion of the DataFrame ```astronauts``` where ```"Gender"``` is equal to ```"Female"``` **or** ```Status``` is equal to ```"Active"```. Notice that when there are more results when there are less conditions.

# %%
astronauts[(astronauts["Gender"] == "Female") | (astronauts["Status"] == "Active")]
# Out:
#                       Name    Year  Group   Status  Birth Date  \
# 0          Joseph M. Acaba  2004.0   19.0   Active   5/17/1967
# 11    Dominic A. Antonelli  2000.0   18.0   Active   8/23/1967
# 15   Richard R. Arnold II   2004.0   19.0   Active  11/26/1963
# 17         Serena M. Aunon  2009.0   20.0   Active    4/9/1976
# 19          Ellen S. Baker  1984.0   10.0  Retired   4/27/1953
# ..                     ...     ...    ...      ...         ...
# 346    Jeffrey N. Williams  1996.0   16.0   Active   1/18/1958
# 347     Sunita L. Williams  1998.0   17.0   Active   9/19/1965
# 348       Barry E. Wilmore  2000.0   18.0   Active  12/29/1962
# 349    Stephanie D. Wilson  1996.0   16.0   Active   9/27/1966
# 350        G. Reid Wiseman  2009.0   20.0   Active  11/11/1975
#
#            Birth Place  Gender  \
# 0        Inglewood, CA    Male
# 11         Detroit, MI    Male
# 15        Cheverly, MD    Male
# 17    Indianapolis, IN  Female
# 19   Fayettesville, NC  Female
# ...

# %% [markdown]
# ## Done!! :)

# %% [markdown]
# ### About this notebook:
# #### Developed by:
# * [Kyra Yee](https://www.linkedin.com/in/kyrayee/)
# * [Amy Tran](https://www.linkedin.com/in/amytran2303/)
#
#
# #### Connect with us:
# <a href='https://www.linkedin.com/company/lanlearning/'> <img src=https://img.icons8.com/color/48/000000/linkedin.png width="48" height="48" align="left"/></a>
#
# <a href='http://www.instagram.com/lanlearning'> <img src=https://img.icons8.com/fluent/48/000000/instagram-new.png width="48" height="48" align="left"/></a>
#
# <a href='https://www.youtube.com/channel/UC5_yxU9pz4ka7xITJMxO5WA'> <img src=https://img.icons8.com/color/48/000000/youtube-squared.png width="48" height="48" align="left"/></a>
#
# <a href='https://www.github.com/lanlearning/'> <img src=https://img.icons8.com/material-rounded/48/000000/github.png/ width="48" height="48" align="left"/></a>
